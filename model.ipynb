# %%
import pandas as pd

target = pd.read_excel('full.xlsx', parse_dates=['Отчетная дата'])
target.head()
# Out:
#   Отчетная дата  Просроченная задолженность по кредитам  \
# 0    2009-04-01                                  346769
# 1    2009-05-01                                  380065
# 2    2009-06-01                                  409667
# 3    2009-07-01                                  428450
# 4    2009-08-01                                  478269
#
#    добыча полезных ископаемых  \
# 0                        3084
# 1                        4032
# 2                        3235
# 3                        5346
# 4                        7519
#
#    добыча топливно-энергетических полезных ископаемых  \
# 0                                               1813
# 1                                               1871
# 2                                               1967
# 3                                               2732
# 4                                               2067
#
#    обрабатывающие производства  \
# 0                        69830
# 1                        74435
# ...

# %%
target['Отчетная дата'] = pd.to_datetime(target['Отчетная дата'])
target.index = target['Отчетная дата']

# %%
target['Просроченная задолженность по кредитам'].plot()
# Out:
# <Axes: xlabel='Отчетная дата'>
